# %%
# Python3 샘플 코드 #


import requests

url = 'http://apis.data.go.kr/1220000/nitemtrade/getNitemtradeList'
params ={'serviceKey' : '%2FCCsTzBRWI3tqG8UoqCp5sl75rjVqhVZJ1c9C6LeXkxkBdQF5s0sSYkLLBwyX98XocH9%2FpeUzWMCsgx9YVnnbA%3D%3D', 'strtYymm' : '201601', 'endYymm' : '201601', 'hsSgn' : '1001999090', 'cntyCd' : 'US' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
#pip install xmltodict
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
hs = ['8479501000','8479502000','8479509000','8515211010','8515212010','8515213010','8515219010','8515311010','8515319010','8486309020','8424202010','8479892010','8479892090','8428701000','8427103000','8428702000','8428709000','8508111000','8508192000']

# %%
import requests
from urllib import parse

url = 'http://apis.data.go.kr/1220000/nitemtrade/getNitemtradeList'
key = "%2FCCsTzBRWI3tqG8UoqCp5sl75rjVqhVZJ1c9C6LeXkxkBdQF5s0sSYkLLBwyX98XocH9%2FpeUzWMCsgx9YVnnbA%3D%3D" 

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&'+parse.urlencode({parse.quote_plus('strtYymm'):'202201',
                                                                           parse.quote_plus('endYymm'):'202212',
                                                                           parse.quote_plus('hsSgn'):'8479501000',
                                                                           parse.quote_plus('cntyCd'):''})

request2 = requests.get(url + queryParams)
print(request2.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>정상서비스.</resultMsg></header><body><items><item><balPayments>-7585823</balPayments><expDlr>5262184</expDlr><expWgt>369060</expWgt><hsCd>-</hsCd><impDlr>12848007</impDlr><impWgt>189429</impWgt><statCd>-</statCd><statCdCntnKor1>-</statCdCntnKor1><statKor>-</statKor><year>총계</year></item><item><balPayments>-549314</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>8479501000</hsCd><impDlr>549314</impDlr><impWgt>17720</impWgt><statCd>CN</statCd><statCdCntnKor1>중국</statCdCntnKor1><statKor>제8479.81호, 제8479.82호, 제8479.89.9010호, 제8479.89-9030호, 제8479.89-9060호, 제8479.89-9091호의 것</statKor><year>2022.01</year></item><item><balPayments>-34934</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>8479501000</hsCd><impDlr>34934</impDlr><impWgt>655</impWgt><statCd>DE</statCd><statCdCntnKor1>독일</statCdCntnKor1><statKor>제8479.81호, 제8479.82호, 제8479.89.9010호, 제8479.89-9030호, 제8479.89-9060호,
# ...

# %%
data = json.loads(json.dumps(xmltodict.parse(request2.text)))

# %%
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': '정상서비스.'},
#   'body': {'items': {'item': [{'balPayments': '-7585823',
#       'expDlr': '5262184',
#       'expWgt': '369060',
#       'hsCd': '-',
#       'impDlr': '12848007',
#       'impWgt': '189429',
#       'statCd': '-',
#       'statCdCntnKor1': '-',
#       'statKor': '-',
#       'year': '총계'},
#      {'balPayments': '-549314',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8479501000',
#       'impDlr': '549314',
#       'impWgt': '17720',
#       'statCd': 'CN',
#       'statCdCntnKor1': '중국',
#       'statKor': '제8479.81호, 제8479.82호, 제8479.89.9010호, 제8479.89-9030호, 제8479.89-9060호, 제8479.89-9091호의 것',
#       'year': '2022.01'},
#      {'balPayments': '-34934',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8479501000',
#       'impDlr': '34934',
#       'impWgt': '655',
#       'statCd': 'DE',
#       'statCdCntnKor1': '독일',
# ...

# %%
df = pd.DataFrame(data['response']['body']['items']['item'])

# %%
df
# Out:
#    balPayments   expDlr  expWgt        hsCd    impDlr  impWgt statCd  \
# 0     -7585823  5262184  369060           -  12848007  189429      -
# 1      -549314        0       0  8479501000    549314   17720     CN
# 2       -34934        0       0  8479501000     34934     655     DE
# 3       759856   759856   19419  8479501000         0       0     ID
# 4      -256494        0       0  8479501000    256494    1071     JP
# ..         ...      ...     ...         ...       ...     ...    ...
# 94      323245   323245   10974  8479501000         0       0     IN
# 95     -843152        0       0  8479501000    843152    4946     JP
# 96     -261056        0       0  8479501000    261056     634     TW
# 97      -71971        0       0  8479501000     71971     799     US
# 98       31000    31000      93  8479501000         0       0     VN
#
#    statCdCntnKor1                                            statKor     year
# ...

# %%
df.to_excel("hscode.xlsx")
